# %% [markdown]
# # EDA Audit
#
# This notebook documents the exploratory data analysis and data quality audit for the churn dataset.
#
# ## Sections
#
# 1. Data ingestion and overview
# 2. Missing values and completeness
# 3. Feature distributions and outliers
# 4. Correlation and relationship checks
# 5. Data quality issues and recommendations
